# %%
import pandas as pd
from glob import glob
from datetime import datetime
glob("data/*")
# Out:
# ['data/Company.csv',
#  'data/CompanyValues.csv',
#  'data/Company_Tweet.csv',
#  'data/Tweet.csv']

# %%
company = pd.read_csv("data/Company.csv")
bridge = pd.read_csv("data/Company_Tweet.csv")
tweet = pd.read_csv("data/Tweet.csv")
company_values = pd.read_csv("data/CompanyValues.csv")
df = tweet.join(bridge.set_index('tweet_id'), on=['tweet_id'], how="left")
company.shape, bridge.shape, tweet.shape, company_values.shape
# Out:
# ((6, 2), (4336445, 2), (3717964, 7), (17528, 7))

# %%
df = tweet.join(bridge.set_index('tweet_id'), on=['tweet_id'], how="left")
df = df.loc[(df['comment_num'] > 0) | (df['retweet_num'] > 0) | (df['like_num'] > 0)]
df
# Out:
#                     tweet_id           writer   post_date  \
# 0         550441509175443456  VisualStockRSRC  1420070457
# 3         550442977802207232     ShowDreamCar  1420070807
# 4         550443807834402816     i_Know_First  1420071005
# 4         550443807834402816     i_Know_First  1420071005
# 5         550443808606126081    aaplstocknews  1420071005
# ...                      ...              ...         ...
# 3717959  1212159765914079234        TEEELAZER  1577836383
# 3717960  1212159838882533376    ShortingIsFun  1577836401
# 3717961  1212160015332728833      Commuternyc  1577836443
# 3717962  1212160410692046849      MoriaCrypto  1577836537
# 3717962  1212160410692046849      MoriaCrypto  1577836537
#
#                                                       body  comment_num  \
# 0        lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 3        $GM $TSLA: Volkswagen Pushes 2014 Record Recal...            0
# ...

# %%
df['post_datetime'] = df['post_date'].apply(lambda x: datetime.fromtimestamp(x))

# %%
df
# Out:
#                     tweet_id           writer   post_date  \
# 0         550441509175443456  VisualStockRSRC  1420070457
# 1         550441672312512512      KeralaGuy77  1420070496
# 2         550441732014223360      DozenStocks  1420070510
# 3         550442977802207232     ShowDreamCar  1420070807
# 4         550443807834402816     i_Know_First  1420071005
# ...                      ...              ...         ...
# 3717960  1212159838882533376    ShortingIsFun  1577836401
# 3717961  1212160015332728833      Commuternyc  1577836443
# 3717962  1212160410692046849      MoriaCrypto  1577836537
# 3717962  1212160410692046849      MoriaCrypto  1577836537
# 3717963  1212160477159206912         treabase  1577836553
#
#                                                       body  comment_num  \
# 0        lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 1        Insanity of today weirdo massive selling. $aap...            0
# ...

# %%
df

# %%
company_values
# Out:
#       ticker_symbol    day_date  close_value    volume  open_value  \
# 0              AAPL  2020-05-29       317.94  38399530      319.25
# 1              AAPL  2020-05-28       318.25  33449100      316.77
# 2              AAPL  2020-05-27       318.11  28236270      316.14
# 3              AAPL  2020-05-26       316.73  31380450      323.50
# 4              AAPL  2020-05-22       318.89  20450750      315.77
# ...             ...         ...          ...       ...         ...
# 17523          TSLA  2019-12-21       405.59  14785210      410.29
# 17524          TSLA  2019-12-22       405.59  14785210      410.29
# 17525          TSLA  2019-12-25       425.25   8054720      418.36
# 17526          TSLA  2019-12-28       430.38   9956827      435.00
# 17527          TSLA  2019-12-29       430.38   9956827      435.00
#
#        high_value  low_value
# 0          321.15   316.4700
# 1          323.44   315.6300
# 2          318.71   313.0900
# 3          324.24   316.5000
# ...

# %%
tweet2.loc[tweet2['comment_num'] > 0]
# Out:
#                     tweet_id          writer   post_date  \
# 22        550452877466935296    TheTrendIsUp  1420073167
# 25        550453624258965505             WSJ  1420073345
# 26        550453897714995200     GillesKLEIN  1420073410
# 57        550466945061908482  The_Dumb_Money  1420076521
# 92        550489146624856064            CNBC  1420081814
# ...                      ...             ...         ...
# 3717947  1212155937588416517     QContrarian  1577835470
# 3717957  1212159254884433921   QuantWolfLine  1577836261
# 3717959  1212159765914079234       TEEELAZER  1577836383
# 3717962  1212160410692046849     MoriaCrypto  1577836537
# 3717962  1212160410692046849     MoriaCrypto  1577836537
#
#                                                       body  comment_num  \
# 22       My biggest winner in 2014: Inverse Volatility ...            1
# 25       Jeff Bezos lost $7.4 billion in Amazon's worst...           21
# ...

# %%
dt = datetime.fromtimestamp(1577836537)
dt
# Out:
# datetime.datetime(2019, 12, 31, 15, 55, 37)
