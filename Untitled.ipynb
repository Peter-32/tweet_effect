# %%
import pandas as pd
from glob import glob
from datetime import datetime, timedelta
glob("data/*")
# Out:
# ['data/Company.csv',
#  'data/CompanyValues.csv',
#  'data/Company_Tweet.csv',
#  'data/Tweet.csv']

# %%
company = pd.read_csv("data/Company.csv")
bridge = pd.read_csv("data/Company_Tweet.csv")
tweet = pd.read_csv("data/Tweet.csv")
company_values = pd.read_csv("data/CompanyValues.csv")
df = tweet.join(bridge.set_index('tweet_id'), on=['tweet_id'], how="left")
company.shape, bridge.shape, tweet.shape, company_values.shape
# Out:
# ((6, 2), (4336445, 2), (3717964, 7), (17528, 7))

# %%
df['new_col'] = df[['col1', 'col2']]

# %%
df = tweet.join(bridge.set_index('tweet_id'), on=['tweet_id'], how="left")
df = df.loc[(df['comment_num'] > 0) | (df['retweet_num'] > 0) | (df['like_num'] > 0)]
df['post_datetime'] = df['post_date'].apply(lambda x: datetime.fromtimestamp(x))
df['tomorrow_date'] = df['post_datetime'].apply(lambda x: (x + timedelta(days=1)).strftime("%Y-%m-%d"))
df = df.join(company_values.set_index(["ticker_symbol", "day_date"]), on=["ticker_symbol", "tomorrow_date"], how="left")
df.dropna(subset=['high_value'], inplace=True)
def get_delta_pct(x, y):
    return (x/y)-1
df['pct_change_tomorrow'] = df[['close_value', 'open_value']].apply(lambda x: get_delta_pct(*x), axis=1).astype(float)
df.drop(['tweet_id', 'post_date', 'post_datetime', 'tomorrow_date', 'volume', 'open_value', 'high_value', 'low_value', 'close_value'], axis='columns', inplace=True)
df
# Out:
#                   writer                                               body  \
# 0        VisualStockRSRC  lx21 made $10,008  on $AAPL -Check it out! htt...
# 3           ShowDreamCar  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...
# 4           i_Know_First  Swing Trading: Up To 8.91% Return In 14 Days h...
# 4           i_Know_First  Swing Trading: Up To 8.91% Return In 14 Days h...
# 5          aaplstocknews  Swing Trading: Up To 8.91% Return In 14 Days h...
# ...                  ...                                                ...
# 3716224          Sofiaan  It has been a great run with $TSLA stock Ross....
# 3716226    StrouseGraham  Commented on $TSLA - Tesla:?sht=q3d8vs&shu=ttf...
# 3716227      M8728205808  but you know what @danahull: better late than ...
# 3716228   ModelYendofICE  People dont get that we are TODAY at 675k for ...
# 3716229       rmattila74  Breaking: Goebbels Associates chief analyst Pe...
#
#          comment_num  retweet_num  like_num ticker_symbol  pct_change_tomorrow
# 0                  0            0         1          AAPL            -0.021627
# 3                  0            0         1          TSLA            -0.003048
# 4                  0            0         1          AAPL            -0.021627
# 4                  0            0         1          TSLA            -0.003048
# 5                  0            0         1          AAPL            -0.021627
# ...              ...          ...       ...           ...                  ...
# 3716224            0            0        27          TSLA             0.032914
# 3716226            0            0         1          TSLA             0.032914
# 3716227            0            0         3          TSLA             0.032914
# 3716228            0            0         6          TSLA             0.032914
# 3716229            4            1        17          TSLA             0.032914
#
# [1779857 rows x 7 columns]

# %%
df
# Out:
#                     tweet_id           writer   post_date  \
# 0         550441509175443456  VisualStockRSRC  1420070457
#